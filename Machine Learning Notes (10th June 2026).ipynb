# %% [markdown]
# **10th June 2026**

# %% [markdown]
# 1) **AI** -> Mimics Like human.
# 2) **ML** ->
#     * Predictive Model,
#     * It will only learn Tabular numerical data,
#     * Convert the categorical data into numerical and train the model,
#     * Mathematics, Linear algebra, probability, statistics, some geometry,
#     * It can work best with a small dataset.
#     * It only works with Forward propagation
#     * There are 3 types of machine learning:
#     * * Supervised Learning
#       * Unsupervised Learning
#       * Reinforcement Learning
# 3) **Deep Learning** -> It's inspired by the human brain (neural network)
#     * Integration and Derivatives
#     * Tabular(ANN), Image(CNN), Audio(RNN), Video(CNN), Text(RNN) any type of data,
#     * It works better with Large datasets,
#     * It has both Forward and backward propagation,
#     * It cant create or generate new things, it only just predicts.
# 4) **Agentic AI and Gen AI**

# %% [markdown]
# **Machine Learning**
# * Supervised Learning
# * Semi Supervised Learning
# * Unsupervised Learning
# * Reinforcement Learning

# %% [markdown]
# **11th June 2026**
